# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae3ca3b1-a1fd-4f6d-a549-0d29de997374" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae3ca3b1-a1fd-4f6d-a549-0d29de997374">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
veri=pd.read_csv("turkey_car_market.csv")
veri
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     16/06/2020   Acura             CL                    -     2015.0
# 2     14/06/2020   Acura             CL                  2.2     1994.0
# 3     11/06/2020   Acura             CL                    -     2013.0
# 4     11/06/2020   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  06/06/2020   Tofaş          Şahin                  1.6     1994.0
# 9040  05/06/2020   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  05/06/2020   Tofaş          Doğan                  SLX     1993.0
# 9042  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# ...

# %%
sns.scatterplot(x="Km",y="Fiyat",data=veri)
plt.show()

# %% [markdown]
#  EN ÇOK ARACA SAHİP OLAN MARKALAR

# %%
top10=veri['Marka'].value_counts().head(11).reset_index()
top10
# Out:
#        Marka  count
# 0    Renault   2079
# 1       Fiat    654
# 2       Opel    647
# 3    Hyundai    639
# 4        BMW    616
# 5   Mercedes    613
# 6       Ford    602
# 7       Audi    430
# 8    Peugeot    421
# 9      Dacia    323
# 10     Honda    263

# %%
top10=veri['Marka'].value_counts()[:10] #NORMALDE HEAD İLE GÖREBİLİRİZ AMA LİSTE ŞEKLİNDE YAZMAMIZ GEREKİYOR ONDAN BÖYLE UZATTIK

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10,6))
plt.bar(top10.index,top10.values)
plt.show()

# %%
veri
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     16/06/2020   Acura             CL                    -     2015.0
# 2     14/06/2020   Acura             CL                  2.2     1994.0
# 3     11/06/2020   Acura             CL                    -     2013.0
# 4     11/06/2020   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  06/06/2020   Tofaş          Şahin                  1.6     1994.0
# 9040  05/06/2020   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  05/06/2020   Tofaş          Doğan                  SLX     1993.0
# 9042  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# ...

# %% [markdown]
# ARAÇLARDA KULLANILAN EN POPÜLER 10 RENK

# %%
top10color = veri['Renk'].value_counts()[:10]  # İlk 10 rengi aldım

markalar = list(top10color.index)  # Renk isimleri listesi
adetler = list(top10color.values)  # Renk adetleri listesi

plt.style.use("ggplot")
plt.figure(figsize=(10,6))

plt.bar(markalar, adetler, color=colors[:len(markalar)])  # Renk uzunluğunu eşitle
plt.xticks(rotation=45)  # X ekseni yazılarını döndür (iç içe geçmemesi için)
plt.xlabel("Renk")
plt.ylabel("Adet")
plt.title("En Popüler 10 Renk")

plt.show()

# %%
veri["Arac Tip"].isnull().sum()
# Out:
# 55

# %%
veri.replace("-", None, inplace=True)  # - OLAN HÜCRELERİ EĞER - VARSA NONE YAZDIR YOKSA AYNI HALDE BIRAK
veri
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     16/06/2020   Acura             CL                 None     2015.0
# 2     14/06/2020   Acura             CL                  2.2     1994.0
# 3     11/06/2020   Acura             CL                 None     2013.0
# 4     11/06/2020   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  06/06/2020   Tofaş          Şahin                  1.6     1994.0
# 9040  05/06/2020   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  05/06/2020   Tofaş          Doğan                  SLX     1993.0
# 9042  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# ...

# %% [markdown]
# EKSİK VERİLERİN GÖRSELLEŞTİRİLMESİ

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
msno.bar(veri,figsize=(9,6))
#BURADA EKSİK VERİLER İÇİN BAR GRAFİĞİ OLUŞTURDUK(ZATEN ÜST KISIMDA EKSİK VERİLER YERİNE NON YAZDIRMIŞTIK ONDAN EKSİK VERİ YOK DİYE GÖZÜKÜYOR) BU GRAFİK HER SÜTUNDAKİ EKSİK VERİ ORANINI GÖSTERİR.
# Out:
# <Axes: >

# %%
veri.head()
# Out:
#   İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0  27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1  16/06/2020   Acura             CL                 None     2015.0
# 2  14/06/2020   Acura             CL                  2.2     1994.0
# 3  11/06/2020   Acura             CL                 None     2013.0
# 4  11/06/2020   Acura             CL                  2.2     2010.0
#
#    Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# 0       Dizel       Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1       Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2  Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3       Dizel            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4       Dizel       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
#
#           Kasa Tipi      Kimden  Durum      Km   Fiyat
# ...

# %%
clio=veri[veri['Arac Tip Grubu']=="Clio"] # CLİO LARIN DEĞERLERİNİ GÖRÜNTÜLEDİK
modelyılı=clio.groupby("Model Yıl") #BURDADA MODEL YILLARINA GRUPLADIK

# %%
modelyılı.head()
# Out:
#      İlan Tarihi    Marka Arac Tip Grubu                 Arac Tip  Model Yıl  \
# 6408  16/06/2020  Renault           Clio  1.5 dCi SportTourer Joy     2013.0
# 6414  16/06/2020  Renault           Clio                1.4 Alize     2006.0
# 6432  15/06/2020  Renault           Clio  1.5 dCi SportTourer Joy     2015.0
# 6434  15/06/2020  Renault           Clio            1.5 DCi Alize     2005.0
# 6436  15/06/2020  Renault           Clio                  1.4 16V     2002.0
# ...          ...      ...            ...                      ...        ...
# 7193  18/04/2020  Renault           Clio                   1.4 RT     1998.0
# 7253  18/04/2020  Renault           Clio                    Diğer     2003.0
# 7275  18/04/2020  Renault           Clio                    Diğer     2006.0
# 7286  18/04/2020  Renault           Clio                    Diğer     2004.0
# 7314  18/04/2020  Renault           Clio                    Diğer     2002.0
#
# ...

# %% [markdown]
# ARAÇLARIN HANGİ VİTES TİPİNDE OLDUĞUNUN ORAN GRAFİĞİ

# %%
vites2=veri['Vites'].value_counts()
plt.pie(vites2.values,labels=vites2.index,autopct="%1.2f%%",explode=[0,0,0.3])
plt.show()

# %%
vites2=veri['Yakıt Turu'].value_counts()
plt.figure(figsize=(10,10))
plt.style.use("fivethirtyeight")
plt.pie(vites2.values,labels=vites2.index,autopct="%1.2f%%")
plt.show()
